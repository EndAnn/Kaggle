# %%
import os
import gc
import time
import copy
import optuna

from pathlib import Path

import numpy as np, pandas as pd, polars as pl

from sklearn.model_selection import GroupKFold
from sklearn.model_selection import StratifiedGroupKFold
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.metrics import roc_auc_score
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import VotingClassifier

from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import RandomOverSampler

import lightgbm as lgb, catboost as cb, xgboost as xgb

from optuna.samplers import TPESampler

# %% [markdown]
# # IMAGE PREDICTIONS

# %%
#EFFNET V1B0
# !python /kaggle/input/isic-script-inference-effnetv1b0-f313ae/main.py /kaggle/input/isic-pytorch-training-baseline-image-only/AUROC0.5171_Loss0.3476_epoch35.bin
# !mv submission.csv submission_effnetv1b0.csv
# Out:
# BEST_WEIGHT = /kaggle/input/isic-pytorch-training-baseline-image-only/AUROC0.5171_Loss0.3476_epoch35.bin
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00,  1.08it/s]

# %%
#TARGET 3
# !python /kaggle/input/isic-2024-pl-submission-script-and-preds1/pl_submission.py
# !mv submission.csv submission_image3.csv
# Out:
# /kaggle/input/isic-2024-pl-submission-script-and-preds1/pl_submission.py:24: DtypeWarning: Columns (51,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_train_meta = pd.read_csv(BASE_DATA_DIR + "train-metadata.csv") # металанные в коде не используются

# %%
# #EVA02
# !python /kaggle/input/isic-script-inference-eva02/main.py /kaggle/input/isic-pytorch-training-baseline-eva02/AUROC0.5177_Loss0.2829_epoch7.bin
# !mv submission.csv submission_eva02.csv

# %%
# #EDGENEXT
# !python /kaggle/input/isic-script-inference-edgenext/main.py /kaggle/input/isic-pytorch-training-edgenext/Final_model.bin
# !mv submission.csv submission_edgenext.csv

# %% [markdown]
# # DATA PREPROCESS

# %%
root = Path('/kaggle/input/isic-2024-challenge')

train_path = root / 'train-metadata.csv'
test_path = root / 'test-metadata.csv'
subm_path = root / 'sample_submission.csv'

id_col = 'isic_id'
target_col = 'target'
group_col = 'patient_id'

err = 1e-5
sampling_ratio = 0.01
seed = 42

num_cols = [
    'age_approx',                        # Approximate age of patient at time of imaging.
    'clin_size_long_diam_mm',            # Maximum diameter of the lesion (mm).+
    'tbp_lv_A',                          # A inside  lesion.+
    'tbp_lv_Aext',                       # A outside lesion.+
    'tbp_lv_B',                          # B inside  lesion.+
    'tbp_lv_Bext',                       # B outside lesion.+
    'tbp_lv_C',                          # Chroma inside  lesion.+
    'tbp_lv_Cext',                       # Chroma outside lesion.+
    'tbp_lv_H',                          # Hue inside the lesion; calculated as the angle of A* and B* in LAB* color space. Typical values range from 25 (red) to 75 (brown).+
    'tbp_lv_Hext',                       # Hue outside lesion.+
    'tbp_lv_L',                          # L inside lesion.+
    'tbp_lv_Lext',                       # L outside lesion.+
    'tbp_lv_areaMM2',                    # Area of lesion (mm^2).+
    'tbp_lv_area_perim_ratio',           # Border jaggedness, the ratio between lesions perimeter and area. Circular lesions will have low values; irregular shaped lesions will have higher values. Values range 0-10.+
    'tbp_lv_color_std_mean',             # Color irregularity, calculated as the variance of colors within the lesion's boundary.
    'tbp_lv_deltaA',                     # Average A contrast (inside vs. outside lesion).+
    'tbp_lv_deltaB',                     # Average B contrast (inside vs. outside lesion).+
    'tbp_lv_deltaL',                     # Average L contrast (inside vs. outside lesion).+
    'tbp_lv_deltaLB',                    #
    'tbp_lv_deltaLBnorm',                # Contrast between the lesion and its immediate surrounding skin. Low contrast lesions tend to be faintly visible such as freckles; high contrast lesions tend to be those with darker pigment. Calculated as the average delta LB of the lesion relative to its immediate background in LAB* color space. Typical values range from 5.5 to 25.+
    'tbp_lv_eccentricity',               # Eccentricity.+
    'tbp_lv_minorAxisMM',                # Smallest lesion diameter (mm).+
    'tbp_lv_nevi_confidence',            # Nevus confidence score (0-100 scale) is a convolutional neural network classifier estimated probability that the lesion is a nevus. The neural network was trained on approximately 57,000 lesions that were classified and labeled by a dermatologist.+,++
    'tbp_lv_norm_border',                # Border irregularity (0-10 scale); the normalized average of border jaggedness and asymmetry.+
    'tbp_lv_norm_color',                 # Color variation (0-10 scale); the normalized average of color asymmetry and color irregularity.+
    'tbp_lv_perimeterMM',                # Perimeter of lesion (mm).+
    'tbp_lv_radial_color_std_max',       # Color asymmetry, a measure of asymmetry of the spatial distribution of color within the lesion. This score is calculated by looking at the average standard deviation in LAB* color space within concentric rings originating from the lesion center. Values range 0-10.+
    'tbp_lv_stdL',                       # Standard deviation of L inside  lesion.+
    'tbp_lv_stdLExt',                    # Standard deviation of L outside lesion.+
    'tbp_lv_symm_2axis',                 # Border asymmetry; a measure of asymmetry of the lesion's contour about an axis perpendicular to the lesion's most symmetric axis. Lesions with two axes of symmetry will therefore have low scores (more symmetric), while lesions with only one or zero axes of symmetry will have higher scores (less symmetric). This score is calculated by comparing opposite halves of the lesion contour over many degrees of rotation. The angle where the halves are most similar identifies the principal axis of symmetry, while the second axis of symmetry is perpendicular to the principal axis. Border asymmetry is reported as the asymmetry value about this second axis. Values range 0-10.+
    'tbp_lv_symm_2axis_angle',           # Lesion border asymmetry angle.+
    'tbp_lv_x',                          # X-coordinate of the lesion on 3D TBP.+
    'tbp_lv_y',                          # Y-coordinate of the lesion on 3D TBP.+
    'tbp_lv_z',                          # Z-coordinate of the lesion on 3D TBP.+
]

new_num_cols = [
    'lesion_size_ratio',                 # tbp_lv_minorAxisMM      / clin_size_long_diam_mm
    'lesion_shape_index',                # tbp_lv_areaMM2          / tbp_lv_perimeterMM **2
    'hue_contrast',                      # tbp_lv_H                - tbp_lv_Hext              abs
    'luminance_contrast',                # tbp_lv_L                - tbp_lv_Lext              abs
    'lesion_color_difference',           # tbp_lv_deltaA **2       + tbp_lv_deltaB **2 + tbp_lv_deltaL **2  sqrt
    'border_complexity',                 # tbp_lv_norm_border      + tbp_lv_symm_2axis
    'color_uniformity',                  # tbp_lv_color_std_mean   / tbp_lv_radial_color_std_max

    'position_distance_3d',              # tbp_lv_x **2 + tbp_lv_y **2 + tbp_lv_z **2  sqrt
    'perimeter_to_area_ratio',           # tbp_lv_perimeterMM      / tbp_lv_areaMM2
    'area_to_perimeter_ratio',           # tbp_lv_areaMM2          / tbp_lv_perimeterMM
    'lesion_visibility_score',           # tbp_lv_deltaLBnorm      + tbp_lv_norm_color
    'symmetry_border_consistency',       # tbp_lv_symm_2axis       * tbp_lv_norm_border
    'consistency_symmetry_border',       # tbp_lv_symm_2axis       * tbp_lv_norm_border / (tbp_lv_symm_2axis + tbp_lv_norm_border)

    'color_consistency',                 # tbp_lv_stdL             / tbp_lv_Lext
    'consistency_color',                 # tbp_lv_stdL*tbp_lv_Lext / tbp_lv_stdL + tbp_lv_Lext
    'size_age_interaction',              # clin_size_long_diam_mm  * age_approx
    'hue_color_std_interaction',         # tbp_lv_H                * tbp_lv_color_std_mean
    'lesion_severity_index',             # tbp_lv_norm_border      + tbp_lv_norm_color + tbp_lv_eccentricity / 3
    'shape_complexity_index',            # border_complexity       + lesion_shape_index
    'color_contrast_index',              # tbp_lv_deltaA + tbp_lv_deltaB + tbp_lv_deltaL + tbp_lv_deltaLBnorm

    'log_lesion_area',                   # tbp_lv_areaMM2          + 1  np.log
    'normalized_lesion_size',            # clin_size_long_diam_mm  / age_approx
    'mean_hue_difference',               # tbp_lv_H                + tbp_lv_Hext    / 2
    'std_dev_contrast',                  # tbp_lv_deltaA **2 + tbp_lv_deltaB **2 + tbp_lv_deltaL **2   / 3  np.sqrt
    'color_shape_composite_index',       # tbp_lv_color_std_mean   + bp_lv_area_perim_ratio + tbp_lv_symm_2axis   / 3
    'lesion_orientation_3d',             # tbp_lv_y                , tbp_lv_x  np.arctan2
    'overall_color_difference',          # tbp_lv_deltaA           + tbp_lv_deltaB + tbp_lv_deltaL   / 3

    'symmetry_perimeter_interaction',    # tbp_lv_symm_2axis       * tbp_lv_perimeterMM
    'comprehensive_lesion_index',        # tbp_lv_area_perim_ratio + tbp_lv_eccentricity + bp_lv_norm_color + tbp_lv_symm_2axis   / 4
    'color_variance_ratio',              # tbp_lv_color_std_mean   / tbp_lv_stdLExt
    'border_color_interaction',          # tbp_lv_norm_border      * tbp_lv_norm_color
    'border_color_interaction_2',
    'size_color_contrast_ratio',         # clin_size_long_diam_mm  / tbp_lv_deltaLBnorm
    'age_normalized_nevi_confidence',    # tbp_lv_nevi_confidence  / age_approx
    'age_normalized_nevi_confidence_2',
    'color_asymmetry_index',             # tbp_lv_symm_2axis       * tbp_lv_radial_color_std_max

    'volume_approximation_3d',           # tbp_lv_areaMM2          * sqrt(tbp_lv_x**2 + tbp_lv_y**2 + tbp_lv_z**2)
    'color_range',                       # abs(tbp_lv_L - tbp_lv_Lext) + abs(tbp_lv_A - tbp_lv_Aext) + abs(tbp_lv_B - tbp_lv_Bext)
    'shape_color_consistency',           # tbp_lv_eccentricity     * tbp_lv_color_std_mean
    'border_length_ratio',               # tbp_lv_perimeterMM      / pi * sqrt(tbp_lv_areaMM2 / pi)
    'age_size_symmetry_index',           # age_approx              * clin_size_long_diam_mm * tbp_lv_symm_2axis
    'index_age_size_symmetry',           # age_approx              * tbp_lv_areaMM2 * tbp_lv_symm_2axis

 ###########NEW###################

    'lesion_compactness',               # tbp_lv_perimeterMM**2 / tbp_lv_areaMM2
    'ellipticity_index',                # (clin_size_long_diam_mm - tbp_lv_minorAxisMM) / clin_size_long_diam_mm
    'border_irregularity_index',        # tbp_lv_norm_border / tbp_lv_area_perim_ratio
    'lesion_color_intensity',           # (tbp_lv_L * tbp_lv_A * tbp_lv_B) / 1000
    'lesion_color_contrast_norm',       # lesion_color_difference / (tbp_lv_Lext + tbp_lv_Aext + tbp_lv_Bext)
    'lesion_circularity',               # (4 * pi * tbp_lv_areaMM2) / tbp_lv_perimeterMM**2
    'volume_to_area_ratio',             # volume_approximation_3d / tbp_lv_areaMM2
    'lesion_spread_index',              # sqrt(tbp_lv_x**2 + tbp_lv_y**2 + tbp_lv_z**2) / tbp_lv_areaMM2
    'gradient_based_color_asymmetry',   # (tbp_lv_stdL - tbp_lv_stdLExt) / tbp_lv_stdL
    'symmetry_to_compactness_ratio',    # tbp_lv_symm_2axis / lesion_compactness
    'age_normalized_severity_index',    # lesion_severity_index / age_approx
    'color_homogeneity',                # 1 / (tbp_lv_radial_color_std_max + err)
    'border_to_hue_contrast_ratio',     # tbp_lv_norm_border / hue_contrast

]

cat_cols = ['sex', 'anatom_site_general', 'tbp_tile_type', 'tbp_lv_location', 'tbp_lv_location_simple', 'attribution']
norm_cols = [f'{col}_patient_norm' for col in num_cols + new_num_cols]
mean_cols = [f'{col}_patient_mean' for col in num_cols + new_num_cols]
special_cols = ['count_per_patient']
image_cols = ["target_3","target_effnetv1b0"]

#norm_cols += image_cols
feature_cols_with_OHE = num_cols + new_num_cols + cat_cols + norm_cols + special_cols + mean_cols
feature_cols_without_OHE = num_cols + new_num_cols + cat_cols + norm_cols + special_cols + mean_cols

# %%
def read_data(path):
    # Чтение данных
    df = (
        pl.read_csv(path)
        .with_columns(
            pl.col('age_approx').cast(pl.String).replace('NA', np.nan).cast(pl.Float64),
        )
        .with_columns(
            pl.col(pl.Float64).fill_nan(pl.col(pl.Float64).median()),  # Impute missing values
        )
        .with_columns(
            lesion_size_ratio              = pl.col('tbp_lv_minorAxisMM') / pl.col('clin_size_long_diam_mm'),
            lesion_shape_index             = pl.col('tbp_lv_areaMM2') / (pl.col('tbp_lv_perimeterMM') ** 2),
            hue_contrast                   = (pl.col('tbp_lv_H') - pl.col('tbp_lv_Hext')).abs(),
            luminance_contrast             = (pl.col('tbp_lv_L') - pl.col('tbp_lv_Lext')).abs(),
            lesion_color_difference        = (pl.col('tbp_lv_deltaA') ** 2 + pl.col('tbp_lv_deltaB') ** 2 + pl.col('tbp_lv_deltaL') ** 2).sqrt(),
            border_complexity              = pl.col('tbp_lv_norm_border') + pl.col('tbp_lv_symm_2axis'),
            color_uniformity               = pl.col('tbp_lv_color_std_mean') / (pl.col('tbp_lv_radial_color_std_max') + err),
        )
        .with_columns(
            position_distance_3d           = (pl.col('tbp_lv_x') ** 2 + pl.col('tbp_lv_y') ** 2 + pl.col('tbp_lv_z') ** 2).sqrt(),
            perimeter_to_area_ratio        = pl.col('tbp_lv_perimeterMM') / pl.col('tbp_lv_areaMM2'),
            area_to_perimeter_ratio        = pl.col('tbp_lv_areaMM2') / pl.col('tbp_lv_perimeterMM'),
            lesion_visibility_score        = pl.col('tbp_lv_deltaLBnorm') + pl.col('tbp_lv_norm_color'),
            combined_anatomical_site       = pl.col('anatom_site_general') + '_' + pl.col('tbp_lv_location'),
            symmetry_border_consistency    = pl.col('tbp_lv_symm_2axis') * pl.col('tbp_lv_norm_border'),
            consistency_symmetry_border    = pl.col('tbp_lv_symm_2axis') * pl.col('tbp_lv_norm_border') / (pl.col('tbp_lv_symm_2axis') + pl.col('tbp_lv_norm_border')),
        )
        .with_columns(
            color_consistency              = pl.col('tbp_lv_stdL') / pl.col('tbp_lv_Lext'),
            consistency_color              = pl.col('tbp_lv_stdL') * pl.col('tbp_lv_Lext') / (pl.col('tbp_lv_stdL') + pl.col('tbp_lv_Lext')),
            size_age_interaction           = pl.col('clin_size_long_diam_mm') * pl.col('age_approx'),
            hue_color_std_interaction      = pl.col('tbp_lv_H') * pl.col('tbp_lv_color_std_mean'),
            lesion_severity_index          = (pl.col('tbp_lv_norm_border') + pl.col('tbp_lv_norm_color') + pl.col('tbp_lv_eccentricity')) / 3,
            shape_complexity_index         = pl.col('border_complexity') + pl.col('lesion_shape_index'),
            color_contrast_index           = pl.col('tbp_lv_deltaA') + pl.col('tbp_lv_deltaB') + pl.col('tbp_lv_deltaL') + pl.col('tbp_lv_deltaLBnorm'),
        )
        .with_columns(
            log_lesion_area                = (pl.col('tbp_lv_areaMM2') + 1).log(),
            normalized_lesion_size         = pl.col('clin_size_long_diam_mm') / pl.col('age_approx'),
            mean_hue_difference            = (pl.col('tbp_lv_H') + pl.col('tbp_lv_Hext')) / 2,
            std_dev_contrast               = ((pl.col('tbp_lv_deltaA') ** 2 + pl.col('tbp_lv_deltaB') ** 2 + pl.col('tbp_lv_deltaL') ** 2) / 3).sqrt(),
            color_shape_composite_index    = (pl.col('tbp_lv_color_std_mean') + pl.col('tbp_lv_deltaA') + pl.col('tbp_lv_symm_2axis')) / 3,
            lesion_orientation_3d          = pl.arctan2(pl.col('tbp_lv_y'), pl.col('tbp_lv_x')),
            overall_color_difference       = (pl.col('tbp_lv_deltaA') + pl.col('tbp_lv_deltaB') + pl.col('tbp_lv_deltaL')) / 3,
        )
        .with_columns(
            symmetry_perimeter_interaction = pl.col('tbp_lv_symm_2axis') * pl.col('tbp_lv_perimeterMM'),
            comprehensive_lesion_index     = (pl.col('tbp_lv_area_perim_ratio') + pl.col('tbp_lv_eccentricity') + pl.col('tbp_lv_norm_color') + pl.col('tbp_lv_symm_2axis')) / 4,
            color_variance_ratio           = pl.col('tbp_lv_color_std_mean') / pl.col('tbp_lv_stdLExt'),
            border_color_interaction       = pl.col('tbp_lv_norm_border') * pl.col('tbp_lv_norm_color'),
            border_color_interaction_2     = pl.col('tbp_lv_norm_border') * pl.col('tbp_lv_norm_color') / (pl.col('tbp_lv_norm_border') + pl.col('tbp_lv_norm_color')),
            size_color_contrast_ratio      = pl.col('clin_size_long_diam_mm') / pl.col('tbp_lv_deltaLBnorm'),
            age_normalized_nevi_confidence = pl.col('tbp_lv_nevi_confidence') / pl.col('age_approx'),
            age_normalized_nevi_confidence_2 = (pl.col('clin_size_long_diam_mm')**2 + pl.col('age_approx')**2).sqrt(),
            color_asymmetry_index          = pl.col('tbp_lv_radial_color_std_max') * pl.col('tbp_lv_symm_2axis'),
        )
        .with_columns(
            volume_approximation_3d        = pl.col('tbp_lv_areaMM2') * (pl.col('tbp_lv_x')**2 + pl.col('tbp_lv_y')**2 + pl.col('tbp_lv_z')**2).sqrt(),
            color_range                    = (pl.col('tbp_lv_L') - pl.col('tbp_lv_Lext')).abs() + (pl.col('tbp_lv_A') - pl.col('tbp_lv_Aext')).abs() + (pl.col('tbp_lv_B') - pl.col('tbp_lv_Bext')).abs(),
            shape_color_consistency        = pl.col('tbp_lv_eccentricity') * pl.col('tbp_lv_color_std_mean'),
            border_length_ratio            = pl.col('tbp_lv_perimeterMM') / (2 * np.pi * (pl.col('tbp_lv_areaMM2') / np.pi).sqrt()),
            age_size_symmetry_index        = pl.col('age_approx') * pl.col('clin_size_long_diam_mm') * pl.col('tbp_lv_symm_2axis'),
            index_age_size_symmetry        = pl.col('age_approx') * pl.col('tbp_lv_areaMM2') * pl.col('tbp_lv_symm_2axis'),
        )
        ###########NEW###################
        .with_columns(
            lesion_compactness             = (pl.col('tbp_lv_perimeterMM')**2) / pl.col('tbp_lv_areaMM2') ,
            ellipticity_index              = (pl.col('clin_size_long_diam_mm') - pl.col('tbp_lv_minorAxisMM')) / pl.col('clin_size_long_diam_mm'),
            border_irregularity_index      = pl.col('tbp_lv_norm_border') / pl.col('tbp_lv_area_perim_ratio'),
            lesion_color_intensity         = (pl.col('tbp_lv_L') * pl.col('tbp_lv_A') * pl.col('tbp_lv_B')) / 1000,
            lesion_color_contrast_norm     = pl.col('lesion_color_difference') / (pl.col('tbp_lv_Lext') + pl.col('tbp_lv_Aext') + pl.col('tbp_lv_Bext')),
            lesion_circularity             = (4 * np.pi * pl.col('tbp_lv_areaMM2')) / (pl.col('tbp_lv_perimeterMM')**2),
            volume_to_area_ratio           = pl.col('volume_approximation_3d') / pl.col('tbp_lv_areaMM2'),
            lesion_spread_index            = (pl.col('tbp_lv_x')**2 + pl.col('tbp_lv_y')**2 + pl.col('tbp_lv_z')**2).sqrt() / pl.col('tbp_lv_areaMM2'),
            gradient_based_color_asymmetry = (pl.col('tbp_lv_stdL') - pl.col('tbp_lv_stdLExt')) / pl.col('tbp_lv_stdL'),
            age_normalized_severity_index  = pl.col('lesion_severity_index') / pl.col('age_approx'),
            color_homogeneity              = 1 / (pl.col('tbp_lv_radial_color_std_max') + err),
            border_to_hue_contrast_ratio   = pl.col('tbp_lv_norm_border') / pl.col('hue_contrast'),
        )
        .with_columns(
            symmetry_to_compactness_ratio  = pl.col('tbp_lv_symm_2axis') / pl.col('lesion_compactness')
        )

        .with_columns(
            ((pl.col(col) - pl.col(col).mean().over('patient_id')) / (pl.col(col).std().over('patient_id') + err)).alias(f'{col}_patient_norm') for col in (num_cols + new_num_cols)
        )
        .with_columns(
            ( pl.col(col).mean().over('patient_id') ).alias(f'{col}_patient_mean') for col in (num_cols + new_num_cols)
        )

        .with_columns(
            count_per_patient = pl.col('isic_id').count().over('patient_id'),
        )
        .with_columns(
            pl.col(cat_cols).cast(pl.Categorical),
        )
    )

    return df.to_pandas().set_index(id_col)

# %%
def preprocess_with_OHE(df_train, df_test):
    global cat_cols

    encoder = OneHotEncoder(sparse_output=False, dtype=np.int32, handle_unknown='ignore')
    encoder.fit(df_train[cat_cols])

    new_cat_cols = [f'onehot_{i}' for i in range(len(encoder.get_feature_names_out()))]

    df_train[new_cat_cols] = encoder.transform(df_train[cat_cols])
#     df_train[new_cat_cols] = df_train[new_cat_cols].astype('category')

    df_test[new_cat_cols] = encoder.transform(df_test[cat_cols])
#     df_test[new_cat_cols] = df_test[new_cat_cols].astype('category')

    # effnetv1b0
    df_eff = pd.read_csv("/kaggle/input/isic-inference-effnetv1b0-for-training-data/train_effnetv1b0.csv")
    df_train = df_train.reset_index(drop=True)
    df_eff = df_eff.reset_index(drop=True)
    df_train["target_effnetv1b0"] = df_eff["target_effnetv1b0"]

    df_eff = pd.read_csv("submission_effnetv1b0.csv")
    df_test = df_test.reset_index(drop=True)
    df_eff = df_eff.reset_index(drop=True)
    df_test["target_effnetv1b0"] = df_eff["target"]

    # target 3
    df_image_3 = pd.read_csv("/kaggle/input/isic-2024-pl-submission-script-and-preds/train_preds.csv")
    df_train = df_train.reset_index(drop=True)
    df_image_3 = df_image_3.reset_index(drop=True)
    df_train["target_3"] = df_image_3["pred"]
    df_3 = pd.read_csv("submission_image3.csv")
    df_test = df_test.reset_index(drop=True)
    df_image_3 = df_image_3.reset_index(drop=True)
    df_test["target_3"] = df_3["target"]

    for col in cat_cols:
        feature_cols_with_OHE.remove(col)

    feature_cols_with_OHE.extend(new_cat_cols)
#     cat_cols = new_cat_cols

    return df_train, df_test

# %%
def preprocess_without_OHE(df_train, df_test):

    # effnetv1b0
    df_eff = pd.read_csv("/kaggle/input/isic-inference-effnetv1b0-for-training-data/train_effnetv1b0.csv")
    df_train = df_train.reset_index(drop=True)
    df_eff = df_eff.reset_index(drop=True)
    df_train["target_effnetv1b0"] = df_eff["target_effnetv1b0"]
    df_eff = pd.read_csv("submission_effnetv1b0.csv")
    df_test = df_test.reset_index(drop=True)
    df_eff = df_eff.reset_index(drop=True)
    df_test["target_effnetv1b0"] = df_eff["target"]

    # target 3
    df_image_3 = pd.read_csv("/kaggle/input/isic-2024-pl-submission-script-and-preds/train_preds.csv")
    df_train = df_train.reset_index(drop=True)
    df_image_3 = df_image_3.reset_index(drop=True)
    df_train["target_3"] = df_image_3["pred"]
    df_3 = pd.read_csv("submission_image3.csv")
    df_test = df_test.reset_index(drop=True)
    df_image_3 = df_image_3.reset_index(drop=True)
    df_test["target_3"] = df_3["target"]

    return df_train, df_test

# %%
def custom_metric(estimator, X, y_true):
    y_hat = estimator.predict_proba(X)[:, 1]
    min_tpr = 0.80
    max_fpr = abs(1 - min_tpr)

    v_gt = abs(y_true - 1)
    v_pred = np.array([1.0 - x for x in y_hat])

    partial_auc_scaled = roc_auc_score(v_gt, v_pred, max_fpr=max_fpr)
    partial_auc = 0.5 * max_fpr**2 + (max_fpr - 0.5 * max_fpr**2) / (1.0 - 0.5) * (partial_auc_scaled - 0.5)

    return partial_auc

# %%
df_train = read_data(train_path)
df_test = read_data(test_path)
df_subm = pd.read_csv(subm_path, index_col=id_col)

df_train_XGB_LGBM, df_test_XGB_LGBM = preprocess_with_OHE(df_train, df_test)
df_train_CB, df_test_CB = preprocess_without_OHE(df_train, df_test)
# Out:
# /tmp/ipykernel_24/942398781.py:16: DtypeWarning: Columns (51,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_eff = pd.read_csv("/kaggle/input/isic-inference-effnetv1b0-for-training-data/train_effnetv1b0.csv")
# /tmp/ipykernel_24/1144721480.py:4: DtypeWarning: Columns (51,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_eff = pd.read_csv("/kaggle/input/isic-inference-effnetv1b0-for-training-data/train_effnetv1b0.csv")

# %% [markdown]
# ***drop least important features with feature importance(code at the last of the notebook before test predictions)***

# %%
# # #they are detected at the first run
# least_important_features = []
# # #they are detected after the least_important_features are removed and it has increased cv score also so I add it

# df_train.drop(columns =least_important_features,inplace = True)

# for feature in least_important_features:
#     cat_cols.remove(feature)
#     feature_cols.remove(feature)

# %% [markdown]
# # MODEL INITIALIZATION

# %%
def lgb_objective(trial):

    params = {
        'objective':         'binary',
        'verbosity':         -1,
        'n_iter': 200,
        'boosting_type':  'gbdt',
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.1),
        'class_weight': trial.suggest_categorical('auto_class_weights', ['balanced']),
        'num_leaves': trial.suggest_int('num_leaves', 15, 250),
        'min_data_in_leaf':trial.suggest_int('min_data_in_leaf', 200, 1000),
        'max_bin': trial.suggest_int('max_bin', 50, 200),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.2, 0.95),
        "bagging_freq":      trial.suggest_int("bagging_freq", 1, 7),
        'lambda_l2':         trial.suggest_float('lambda_l2', 1e-4, 10.0, log=True), # большие значения из диапазона (ближе к 0.001) будут предлагаться чаще, чем большие значения (ближе к 0.1).исп-м широкий диапазон значений, избегая переобучения, которое может произойти при слишком большом значении learning_rate
        "lambda_l1":         trial.suggest_float("lambda_l1", 1e-4, 10.0, log=True),
        'scale_pos_weight' : trial.suggest_float('scale_pos_weight', 0.5, 6.0),

#         'colsample_bytree':  trial.suggest_float('colsample_bytree', 0.4, 1.0),
#         'colsample_bynode':  trial.suggest_float('colsample_bynode', 0.4, 1.0),
        'random_state': 42
    }

    estimator = Pipeline([
        ('sampler', RandomUnderSampler(sampling_strategy=sampling_ratio)),
        ('classifier', lgb.LGBMClassifier(**params)),
    ])

    X = df_train_XGB_LGBM[feature_cols_with_OHE]
    y = df_train_XGB_LGBM[target_col]
    groups = df_train_XGB_LGBM[group_col]
    cv = StratifiedGroupKFold(5, shuffle=True)

    val_score = cross_val_score(
        estimator=estimator,
        X=X, y=y,
        cv=cv,
        groups=groups,
        scoring=custom_metric,
    )

    return np.mean(val_score)

# %%
def xgb_objective(trial):
    params = {
        'objective':          'binary:logistic',
        'n_estimators':       200,
        'tree_method':        'hist',
        'random_state':       seed,
        'learning_rate':      trial.suggest_float('learning_rate', 1e-2, 1e-1, log=True),
        'max_depth':          trial.suggest_int('max_depth', 4, 8),
        'lambda':             trial.suggest_float('lambda', 1e-3, 10.0, log=True),
        'alpha':              trial.suggest_float('alpha', 1e-3, 10.0, log=True),
        'subsample':          trial.suggest_float('subsample', 0.4, 1.0),
        'colsample_bytree':   trial.suggest_float('colsample_bytree', 0.4, 1.0),
        'colsample_bynode':   trial.suggest_float('colsample_bynode', 0.4, 1.0),
        'scale_pos_weight':   trial.suggest_float('scale_pos_weight', 0.8, 4.0),
    }

    estimator = Pipeline([
        ('sampler', RandomUnderSampler(sampling_strategy=sampling_ratio)),
        ('classifier', xgb.XGBClassifier(**params)),
    ])

    X = df_train_XGB_LGBM[feature_cols_with_OHE]
    y = df_train_XGB_LGBM[target_col]
    groups = df_train_XGB_LGBM[group_col]
    cv = StratifiedGroupKFold(5, shuffle=True)

    val_score = cross_val_score(
        estimator=estimator,
        X=X, y=y,
        cv=cv,
        groups=groups,
        scoring=custom_metric,
    )

    return np.mean(val_score)

# %%
DO_TUNING=True

# %%
if DO_TUNING:
    # LightGBM
    start_time = time.time()
    study_lgb = optuna.create_study(direction='maximize', sampler=TPESampler(seed=seed))
    study_lgb.optimize(lgb_objective, n_trials=90)
    end_time = time.time()
    elapsed_time_lgb = end_time - start_time
    print(f"LightGBM tuning took {elapsed_time_lgb:.2f} seconds.")
# Out:
# [I 2025-06-01 15:37:58,089] A new study created in memory with name: no-name-3b07054b-2ade-48be-a3e9-dcd55d206200
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01 15:38:21,882] Trial 0 finished with value: 0.1602796041221647 and parameters: {'learning_rate': 0.03807947176588889, 'auto_class_weights': 'balanced', 'num_leaves': 239, 'min_data_in_leaf': 786, 'max_bin': 140, 'bagging_fraction': 0.31701398033182737, 'bagging_freq': 2, 'lambda_l2': 0.00019517224641449495, 'lambda_l1': 2.1423021757741068, 'scale_pos_weight': 3.8061325645876485}. Best is trial 0 with value: 0.1602796041221647.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01 15:38:48,690] Trial 1 finished with value: 0.15932449693322506 and parameters: {'learning_rate': 0.07109918520180851, 'auto_class_weights': 'balanced', 'num_leaves': 19, 'min_data_in_leaf': 976, 'max_bin': 175, 'bagging_fraction': 0.3592543330087071, 'bagging_freq': 2, 'lambda_l2': 0.0008260808399079611, 'lambda_l1': 0.0033205591037519565, 'scale_pos_weight': 3.386160373977308}. Best is trial 0 with value: 0.1602796041221647.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01 15:39:14,846] Trial 2 finished with value: 0.15788538574182598 and parameters: {'learning_rate': 0.04376255684556946, 'auto_class_weights': 'balanced', 'num_leaves': 83, 'min_data_in_leaf': 690, 'max_bin': 71, 'bagging_fraction': 0.4191084864014136, 'bagging_freq': 3, 'lambda_l2': 0.019069966103000432, 'lambda_l1': 0.8431013932082461, 'scale_pos_weight': 1.5982058018709786}. Best is trial 0 with value: 0.1602796041221647.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01 15:39:41,253] Trial 3 finished with value: 0.16031397343498843 and parameters: {'learning_rate': 0.051909209402947555, 'auto_class_weights': 'balanced', 'num_leaves': 154, 'min_data_in_leaf': 237, 'max_bin': 141, 'bagging_fraction': 0.32789309276546863, 'bagging_freq': 1, 'lambda_l2': 5.5517216852447255, 'lambda_l1': 6.732248920775331, 'scale_pos_weight': 4.946185414640536}. Best is trial 3 with value: 0.16031397343498843.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01 15
. Best is trial 7 with value: 0.16703918349429583.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01 15:43:52,679] Trial 11 finished with value: 0.16205529148643755 and parameters: {'learning_rate': 0.016028558727545335, 'auto_class_weights': 'balanced', 'num_leaves': 141, 'min_data_in_leaf': 457, 'max_bin': 110, 'bagging_fraction': 0.6218980269995947, 'bagging_freq': 1, 'lambda_l2': 7.034880741184682, 'lambda_l1': 0.10862289420171273, 'scale_pos_weight': 4.284543939071821}. Best is trial 7 with value: 0.16703918349429583.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01 15:44:28,312] Trial 12 finished with value: 0.16342163686227631 and parameters: {'learning_rate': 0.015110613467219392, 'auto_class_weights': 'balanced', 'num_leaves': 125, 'min_data_in_leaf': 452, 'max_bin': 104, 'bagging_fraction': 0.6568053975753085, 'bagging_freq': 1, 'lambda_l2': 0.7238024718020855, 'lambda_l1': 0.08281115256437815, 'scale_pos_weight': 4.10287804136736}. Best is trial 7 with value: 0.16703918349429583.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01 15:45:09,115] Trial 13 finished with value: 0.16545672882023124 and parameters: {'learning_rate': 0.02348676215343697, 'auto_class_weights': 'balanced', 'num_leaves': 111, 'min_data_in_leaf': 472, 'max_bin': 200, 'bagging_fraction': 0.6933420788807901, 'bagging_freq': 2, 'lambda_l2': 0.8533258017594572, 'lambda_l1': 0.27266754859162545, 'scale_pos_weight': 2.529750104098687}. Best is trial 7 with value: 0.16703918349429583.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01 15:45:50,983] Trial 14 finished with value: 0.1665423674068674 and parameters: {'learning_rate': 0.02679174883821366, 'auto_class_weights': 'balanced', 'num_leaves': 60, 'min_data_in_leaf': 562, 'max_bin': 200, 'bagging_fraction': 0.7832837026302057, 'bagging_freq': 3, 'lambda_l2': 0.8811507241578517, 'lambda_l1': 0.4341190432333087, 'scale_pos_weight': 2.2646759824089937}. Best is trial 7 with value: 0.16703918349429583.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01 15:46:28,106] Trial 15 finished with value: 0.15704908995277161 and parameters: {'learning_rate': 0.004547967099368711, 'auto_class_weights': 'balanced', 'num_leaves': 56, 'min_data_in_leaf': 575, 'max_bin': 191, 'bagging_fraction': 0.8625477907339825, 'bagging_freq': 4, 'lambda_l2': 0.15177448539413993, 'lambda_l1': 0.015771344409444988, 'scale_pos_weight': 0.7493238917629902}. Best is trial 7 with value: 0.16703918349429583.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01 15:47:04,758] Trial 16 finished with value: 0.16581773902201785 and parameters: {'learning_rate': 0.03266738478609185, 'auto_class_weights': 'balanced', 'num_leaves': 58, 'min_data_in_leaf': 914, 'max_bin': 157, 'bagging_fraction': 0.7728105461861396, 'bagging_freq': 3, 'lambda_l2': 1.5022033694817722, 'lambda_l1': 0.4313439975820845, 'scale_pos_weight': 1.763295664228445}. Best is trial 7 with value: 0.16703918349429583.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01 15:47:37,315] Trial 17 finished with value: 0.15967185184281024 and parameters: {'learning_rate': 0.04788043781312783, 'auto_class_weights': 'balanced', 'num_leaves': 58, 'min_data_in_leaf': 565, 'max_bin': 85, 'bagging_fraction': 0.5330377727938387, 'bagging_freq': 5, 'lambda_l2': 0.13711947225618534, 'lambda_l1': 0.012397017239447193, 'scale_pos_weight': 2.5177571823755063}. Best is trial 7 with value: 0.16703918349429583.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01 15:48:12,145] Trial 18 finished with value: 0.16530419730657514 and parameters: {'learning_rate': 0.0875489461264603, 'auto_class_weights': 'balanced', 'num_leaves': 172, 'min_data_in_leaf': 359, 'max_bin': 50, 'bagging_fraction': 0.7602090519694724, 'bagging_freq': 2, 'lambda_l2': 2.670507669230323, 'lambda_l1': 0.8366024940133311, 'scale_pos_weight': 1.227497753072033}. Best is trial 7 with value: 0.16703918349429583.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01 15:48:50,801] Trial 19 finished with value: 0.16417366572601583 and parameters: {'learning_rate': 0.023214521644490692, 'auto_class_weights': 'balanced', 'num_leaves': 17, 'min_data_in_leaf': 857, 'max_bin': 179, 'bagging_fraction': 0.9310701993921858, 'bagging_freq': 4, 'lambda_l2': 0.3428118804404232, 'lambda_l1': 0.9127195010969923, 'scale_pos_weight': 2.348167706113029}. Best is trial 7 with value: 0.16703918349429583.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01 15:49:22,293] Trial 20 finished with value: 0.15541714983505864 and parameters: {'learning_rate': 0.07939190150031086, 'auto_class_weights': 'balanced', 'num_leaves': 110, 'min_data_in_leaf': 653, 'max_bin': 65, 'bagging_fraction': 0.542040338558593, 'bagging_freq': 3, 'lambda_l2': 0.03509006551126995, 'lambda_l1': 0.03968272127893513, 'scale_pos_weight': 5.966135317773398}. Best is trial 7 with value: 0.16703918349429583.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01 15:50:00,329] Trial 21 finished with value: 0.16567863971185356 and parameters: {'learning_rate': 0.0342883735470472, 'auto_class_weights': 'balanced', 'num_leaves': 60, 'min_data_in_leaf': 902, 'max_bin': 159, 'bagging_fraction': 0.8228909116862692, 'bagging_freq': 3, 'lambda_l2': 1.8167590082015723, 'lambda_l1': 0.3888165610821739, 'scale_pos_weight': 1.5114016025680697}. Best is trial 7 with value: 0.16703918349429583.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01 15:50:33,420] Trial 22 finished with value: 0.1653875004835272 and parameters: {'learning_rate': 0.0255619930291616, 'auto_class_weights': 'balanced', 'num_leaves': 71, 'min_data_in_leaf': 999, 'max_bin': 155, 'bagging_fraction': 0.7232328884316138, 'bagging_freq': 5, 'lambda_l2': 2.5626606102391953, 'lambda_l1': 0.2816038630665225, 'scale_pos_weight': 2.133663231513567}. Best is trial 7 with value: 0.16703918349429583.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01 15:51:15,684] Trial 23 finished with value: 0.1628347176018694 and parameters: {'learning_rate': 0.04103120379315821, 'auto_class_weights': 'balanced', 'num_leaves': 42, 'min_data_in_leaf': 517, 'max_bin': 176, 'bagging_fraction': 0.8572576742812467, 'bagging_freq': 3, 'lambda_l2': 9.641974576943944, 'lambda_l1': 1.280790465416607, 'scale_pos_weight': 2.894035521626472}. Best is trial 7 with value: 0.16703918349429583.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01 15:51:57,467] Trial 24 finished with value: 0.16625090271397636 and parameters: {'learning_rate': 0.055415997691382474, 'auto_class_weights': 'balanced', 'num_leaves': 34, 'min_data_in_leaf': 354, 'max_bin': 127, 'bagging_fraction': 0.787867772582981, 'bagging_freq': 2, 'lambda_l2': 1.7548535740019744, 'lambda_l1': 0.360504444917508, 'scale_pos_weight': 1.193122783365457}. Best is trial 7 with value: 0.16703918349429583.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01 15:52:35,305] Trial 25 finished with value: 0.1580540241319615 and parameters: {'learning_rate': 0.052964933456826985, 'auto_class_weights': 'balanced', 'num_leaves': 34, 'min_data_in_leaf': 334, 'max_bin': 120, 'bagging_fraction': 0.59648474616078, 'bagging_freq': 2, 'lambda_l2': 0.3951541541321414, 'lambda_l1': 0.037878484941346616, 'scale_pos_weight': 1.1023567727853465}. Best is trial 7 with value: 0.16703918349429583.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01 15:53:23,667] Trial 26 finished with value: 0.16375390749005864 and parameters: {'learning_rate': 0.0568066073751585, 'auto_class_weights': 'balanced', 'num_leaves': 108, 'min_data_in_leaf': 349, 'max_bin': 91, 'bagging_fraction': 0.8828314897651773, 'bagging_freq': 1, 'lambda_l2': 0.05136218631822008, 'lambda_l1': 0.00013385758222832526, 'scale_pos_weight': 1.2185428697361056}. Best is trial 7 with value: 0.16703918349429583.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01 15:53:57,589] Trial 27 finished with value: 0.16330529658344375 and parameters: {'learning_rate': 0.012340746707565162, 'auto_class_weights': 'balanced', 'num_leaves': 78, 'min_data_in_leaf': 520, 'max_bin': 127, 'bagging_fraction': 0.8130775593969688, 'bagging_freq': 2, 'lambda_l2': 3.2832780093634915, 'lambda_l1': 0.16283186741489744, 'scale_pos_weight': 0.5625845518131011}. Best is trial 7 with value: 0.16703918349429583.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01 15:54:33,410] Trial 28 finished with value: 0.16514184435782925 and parameters: {'learning_rate': 0.04579030191136295, 'auto_class_weights': 'balanced', 'num_leaves': 31, 'min_data_in_leaf': 633, 'max_bin': 102, 'bagging_fraction': 0.7056571305668053, 'bagging_freq': 1, 'lambda_l2': 0.33643027705171946, 'lambda_l1': 1.4150314685765346, 'scale_pos_weight': 2.8245137449525135}. Best is trial 7 with value: 0.16703918349429583.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01 15:55:09,898] Trial 29 finished with value: 0.1649389285624226 and parameters: {'learning_rate': 0.03765387095905095, 'auto_class_weights': 'balanced', 'num_leaves': 98, 'min_data_in_leaf': 713, 'max_bin': 145, 'bagging_fraction': 0.6567278953766469, 'bagging_freq': 2, 'lambda_l2': 0.0009728187748729736, 'lambda_l1': 0.07040405159607803, 'scale_pos_weight': 2.0637443549626924}. Best is trial 7 with value: 0.16703918349429583.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01 15:55:46,765] Trial 30 finished with value: 0.1612305356060203 and parameters: {'learning_rate': 0.028201897608437908, 'auto_class_weights': 'balanced', 'num_leaves': 46, 'min_data_in_leaf': 812, 'max_bin': 61, 'bagging_fraction': 0.889696583517184, 'bagging_freq': 2, 'lambda_l2': 1.4944589019146373, 'lambda_l1': 2.1024233487565334, 'scale_pos_weight': 3.4856210206396794}. Best is trial 7 with value: 0.16703918349429583.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# ...
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01 16:29:38,000] Trial 79 finished with value: 0.1624080943037425 and parameters: {'learning_rate': 0.0390357832332829, 'auto_class_weights': 'balanced', 'num_leaves': 167, 'min_data_in_leaf': 476, 'max_bin': 155, 'bagging_fraction': 0.9027375038901861, 'bagging_freq': 4, 'lambda_l2': 0.6838592030120428, 'lambda_l1': 0.0007089324512752251, 'scale_pos_weight': 1.0783619287444697}. Best is trial 68 with value: 0.16910658756317715.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01 16:30:25,237] Trial 80 finished with value: 0.17117780885872408 and parameters: {'learning_rate': 0.025554664888037208, 'auto_class_weights': 'balanced', 'num_leaves': 217, 'min_data_in_leaf': 523, 'max_bin': 190, 'bagging_fraction': 0.8281147049112076, 'bagging_freq': 3, 'lambda_l2': 0.06607163051401742, 'lambda_l1': 0.00015559287678760844, 'scale_pos_weight': 1.760048194662142}. Best is trial 80 with value: 0.17117780885872408.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01 16:31:12,314] Trial 81 finished with value: 0.16643959993169782 and parameters: {'learning_rate': 0.02499449560658212, 'auto_class_weights': 'balanced', 'num_leaves': 216, 'min_data_in_leaf': 527, 'max_bin': 189, 'bagging_fraction': 0.8313871583087193, 'bagging_freq': 3, 'lambda_l2': 0.04096476378965919, 'lambda_l1': 0.00017273211568795044, 'scale_pos_weight': 1.7992607931522226}. Best is trial 80 with value: 0.17117780885872408.
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# /opt/conda/lib/python3.10/site-packages/lightgbm/engine.py:172: UserWarning: Found `n_iter` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [I 2025-06-01 16:37:11,967] Trial 89 finished with value: 0.1632583339624059 and parameters: {'learning_rate': 0.036016249860753205, 'auto_class_weights': 'balanced', 'num_leaves': 231, 'min_data_in_leaf': 526, 'max_bin': 165, 'bagging_fraction': 0.8415441825945892, 'bagging_freq': 3, 'lambda_l2': 1.151553097625287, 'lambda_l1': 0.0003017693835919679, 'scale_pos_weight': 2.9163813783526242}. Best is trial 80 with value: 0.17117780885872408.
# LightGBM tuning took 3553.88 seconds.

# %%
def cb_objective(trial):
#     cat_features = [i for i, col in enumerate(df_train.columns) if df_train[col].dtype == 'category']

    params = {
        'loss_function':     'Logloss',
        'iterations':        200,
        'verbose':           False,
        'random_state':      seed,
        'learning_rate':     trial.suggest_float('learning_rate', 1e-2, 1e-1, log=True),
        'max_depth':         trial.suggest_int('max_depth', 4, 8),
        'l2_leaf_reg':       trial.suggest_float('l2_leaf_reg', 1e-3, 10.0, log=True),
        'subsample':         trial.suggest_float('subsample', 0.4, 1.0),
        'colsample_bylevel': trial.suggest_float('colsample_bylevel', 0.4, 1.0),
        'min_data_in_leaf':  trial.suggest_int('min_data_in_leaf', 5, 100),
        'scale_pos_weight':  trial.suggest_float('scale_pos_weight', 0.8, 4.0),
        'bootstrap_type':    'Bernoulli',
        'cat_features':      cat_cols,
    }

    estimator = Pipeline([
        ('sampler', RandomUnderSampler(sampling_strategy=sampling_ratio)),
        ('classifier', cb.CatBoostClassifier(**params)),
    ])

    X = df_train_CB[feature_cols_without_OHE]
    y = df_train_CB[target_col]

    groups = df_train_CB[group_col]

    cv = StratifiedGroupKFold(5, shuffle=True)

    val_score = cross_val_score(
        estimator=estimator,
        X=X, y=y,
        cv=cv,
        groups=groups,
        scoring=custom_metric,
    )

    return np.mean(val_score)

# %%
if DO_TUNING:
    # CatBoost
    start_time = time.time()
    study_cb = optuna.create_study(direction='maximize', sampler=TPESampler(seed=seed))
    study_cb.optimize(cb_objective, n_trials=60)
    end_time = time.time()
    elapsed_time_cb = end_time - start_time
    print(f"CatBoost tuning took {elapsed_time_cb:.2f} seconds.")
# Out:
# [I 2025-06-01 16:37:12,136] A new study created in memory with name: no-name-1d1258dc-a0b3-401c-b57c-54e74c9f3133
# [I 2025-06-01 16:39:57,837] Trial 0 finished with value: 0.16019108115507677 and parameters: {'learning_rate': 0.023688639503640783, 'max_depth': 8, 'l2_leaf_reg': 0.8471801418819978, 'subsample': 0.759195090518222, 'colsample_bylevel': 0.4936111842654619, 'min_data_in_leaf': 19, 'scale_pos_weight': 0.9858675589382383}. Best is trial 0 with value: 0.16019108115507677.
# [I 2025-06-01 16:41:43,563] Trial 1 finished with value: 0.15622107470073282 and parameters: {'learning_rate': 0.07348118405270448, 'max_depth': 7, 'l2_leaf_reg': 0.679657809075816, 'subsample': 0.41235069657748147, 'colsample_bylevel': 0.9819459112971965, 'min_data_in_leaf': 84, 'scale_pos_weight': 1.4794851541704839}. Best is trial 0 with value: 0.16019108115507677.
# [I 2025-06-01 18:57:53,011] Trial 56 finished with value: 0.16319907623974275 and parameters: {'learning_rate': 0.06748726273214782, 'max_depth': 7, 'l2_leaf_reg': 3.827380199826869, 'subsample': 0.9402607906552454, 'colsample_bylevel': 0.712156391096869, 'min_data_in_leaf': 83, 'scale_pos_weight': 3.142718528013252}. Best is trial 51 with value: 0.16663846921233902.
# [I 2025-06-01 18:58:39,147] Trial 57 finished with value: 0.16227397771309646 and parameters: {'learning_rate': 0.05520699338391974, 'max_depth': 4, 'l2_leaf_reg': 4.163070133238405, 'subsample': 0.9703330029359727, 'colsample_bylevel': 0.7377100255032125, 'min_data_in_leaf': 31, 'scale_pos_weight': 3.2860428836940034}. Best is trial 51 with value: 0.16663846921233902.
# [I 2025-06-01 19:02:14,544] Trial 58 finished with value: 0.15767722407841261 and parameters: {'learning_rate': 0.08676301202799425, 'max_depth': 8, 'l2_leaf_reg': 2.1272875078784943, 'subsample': 0.8749017466252578, 'colsample_bylevel': 0.9015418227685948, 'min_data_in_leaf': 90, 'scale_pos_weight': 2.0821147011220833}. Best is trial 51 with value: 0.16663846921233902.
# [I 2025-06-01 19:03:38,824] Trial 59 finished with value: 0.1562473762270439 and parameters: {'learning_rate': 0.02799320938072311, 'max_depth': 6, 'l2_leaf_reg': 0.03006091712618553, 'subsample': 0.8434168500348949, 'colsample_bylevel': 0.757596654260481, 'min_data_in_leaf': 97, 'scale_pos_weight': 2.7460749478764335}. Best is trial 51 with value: 0.16663846921233902.
# CatBoost tuning took 8786.69 seconds.

# %%
if DO_TUNING:
    # XGBoost
    start_time = time.time()
    study_xgb = optuna.create_study(direction='maximize', sampler=TPESampler(seed=seed))
    study_xgb.optimize(xgb_objective, n_trials=60)
    end_time = time.time()
    elapsed_time_xgb = end_time - start_time
    print(f"XGBoost tuning took {elapsed_time_xgb:.2f} seconds.")
# Out:
# [I 2025-06-01 19:03:38,933] A new study created in memory with name: no-name-54b2a309-f885-4fd3-a319-d95319d0add3
# [I 2025-06-01 19:04:34,458] Trial 0 finished with value: 0.1652810863241569 and parameters: {'learning_rate': 0.023688639503640783, 'max_depth': 8, 'lambda': 0.8471801418819978, 'alpha': 0.24810409748678125, 'subsample': 0.4936111842654619, 'colsample_bytree': 0.49359671220172163, 'colsample_bynode': 0.4348501673009197, 'scale_pos_weight': 3.571763666479793}. Best is trial 0 with value: 0.1652810863241569.
# [I 2025-06-01 19:05:26,940] Trial 1 finished with value: 0.1669207775334132 and parameters: {'learning_rate': 0.039913058785616795, 'max_depth': 7, 'lambda': 0.0012087541473056963, 'alpha': 7.579479953348009, 'subsample': 0.899465584480253, 'colsample_bytree': 0.5274034664069657, 'colsample_bynode': 0.5090949803242604, 'scale_pos_weight': 1.3868944315309881}. Best is trial 1 with value: 0.1669207775334132.
. Best is trial 17 with value: 0.17291453494321074.
# [I 2025-06-01 19:58:05,577] Trial 53 finished with value: 0.17103351656689086 and parameters: {'learning_rate': 0.04226025779547763, 'max_depth': 7, 'lambda': 0.018007207836816648, 'alpha': 0.5094193855197492, 'subsample': 0.4690421063208526, 'colsample_bytree': 0.7270267693253222, 'colsample_bynode': 0.7941502619845477, 'scale_pos_weight': 2.7290302290971753}. Best is trial 17 with value: 0.17291453494321074.
# [I 2025-06-01 19:59:07,178] Trial 54 finished with value: 0.1659646458180203 and parameters: {'learning_rate': 0.061305684773545165, 'max_depth': 7, 'lambda': 0.016831518798565617, 'alpha': 0.46964851075773073, 'subsample': 0.48350943900540977, 'colsample_bytree': 0.7088602942347617, 'colsample_bynode': 0.7819828175035995, 'scale_pos_weight': 2.751907041881086}. Best is trial 17 with value: 0.17291453494321074.
# [I 2025-06-01 19:59:50,785] Trial 55 finished with value: 0.16869365025885472 and parameters: {'learning_rate': 0.02889689594293785, 'max_depth': 5, 'lambda': 0.08431129010262509, 'alpha': 0.7478804283821497, 'subsample': 0.4161787265896558, 'colsample_bytree': 0.5799362424082907, 'colsample_bynode': 0.7383964287368368, 'scale_pos_weight': 2.3385422901420845}. Best is trial 17 with value: 0.17291453494321074.
# [I 2025-06-01 20:01:02,299] Trial 56 finished with value: 0.16741436530160408 and parameters: {'learning_rate': 0.03723536423161405, 'max_depth': 8, 'lambda': 0.007720798768808703, 'alpha': 1.817451741885673, 'subsample': 0.6818203352246841, 'colsample_bytree': 0.6332613294845937, 'colsample_bynode': 0.8008568155849489, 'scale_pos_weight': 2.7981339476355025}. Best is trial 17 with value: 0.17291453494321074.
# [I 2025-06-01 20:02:03,646] Trial 57 finished with value: 0.16970190143102235 and parameters: {'learning_rate': 0.07271436900780331, 'max_depth': 7, 'lambda': 0.04596053122276383, 'alpha': 1.1095120640513383, 'subsample': 0.5753178501415784, 'colsample_bytree': 0.7269761932769453, 'colsample_bynode': 0.669154263180499, 'scale_pos_weight': 2.4203662027927133}. Best is trial 17 with value: 0.17291453494321074.
# [I 2025-06-01 20:02:46,216] Trial 58 finished with value: 0.1669159586410565 and parameters: {'learning_rate': 0.05145690227526908, 'max_depth': 4, 'lambda': 0.00529963680304614, 'alpha': 0.030146064136978054, 'subsample': 0.9977302432616866, 'colsample_bytree': 0.782080035362199, 'colsample_bynode': 0.8511528049965618, 'scale_pos_weight': 2.6299376691572727}. Best is trial 17 with value: 0.17291453494321074.
# [I 2025-06-01 20:03:37,308] Trial 59 finished with value: 0.16991329256451643 and parameters: {'learning_rate': 0.043803698246107185, 'max_depth': 6, 'lambda': 0.33356325583228996, 'alpha': 0.0655905151242944, 'subsample': 0.7906876780301154, 'colsample_bytree': 0.5485363397852631, 'colsample_bynode': 0.6876786315927376, 'scale_pos_weight': 2.2474797398191413}. Best is trial 17 with value: 0.17291453494321074.
# XGBoost tuning took 3598.38 seconds.

# %%
if DO_TUNING:
    # Print best parameters for each study
    print("Best LGBM trial:", study_lgb.best_trial)
    print("Best CatBoost trial:", study_cb.best_trial)
    print("Best XGBoost trial:", study_xgb.best_trial)
# Out:
# Best LGBM trial: FrozenTrial(number=80, state=TrialState.COMPLETE, values=[0.17117780885872408], datetime_start=datetime.datetime(2025, 6, 1, 16, 29, 38, 1979), datetime_complete=datetime.datetime(2025, 6, 1, 16, 30, 25, 236649), params={'learning_rate': 0.025554664888037208, 'auto_class_weights': 'balanced', 'num_leaves': 217, 'min_data_in_leaf': 523, 'max_bin': 190, 'bagging_fraction': 0.8281147049112076, 'bagging_freq': 3, 'lambda_l2': 0.06607163051401742, 'lambda_l1': 0.00015559287678760844, 'scale_pos_weight': 1.760048194662142}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'learning_rate': FloatDistribution(high=0.1, log=False, low=0.001, step=None), 'auto_class_weights': CategoricalDistribution(choices=('balanced',)), 'num_leaves': IntDistribution(high=250, log=False, low=15, step=1), 'min_data_in_leaf': IntDistribution(high=1000, log=False, low=200, step=1), 'max_bin': IntDistribution(high=200, log=False, low=50, step=1), 'bagging_fraction': FloatDistribution(high=0.95, log=False, low=0.2, step=None), 'bagging_freq': IntDistribution(high=7, log=False, low=1, step=1), 'lambda_l2': FloatDistribution(high=10.0, log=True, low=0.0001, step=None), 'lambda_l1': FloatDistribution(high=10.0, log=True, low=0.0001, step=None), 'scale_pos_weight': FloatDistribution(high=6.0, log=False, low=0.5, step=None)}, trial_id=80, value=None)
# Best CatBoost trial: FrozenTrial(number=51, state=TrialState.COMPLETE, values=[0.16663846921233902], datetime_start=datetime.datetime(2025, 6, 1, 18, 38, 40, 193052), datetime_complete=datetime.datetime(2025, 6, 1, 18, 42, 2, 153904), params={'learning_rate': 0.03656588364327307, 'max_depth': 8, 'l2_leaf_reg': 3.482772362697588, 'subsample': 0.8873911263760219, 'colsample_bylevel': 0.6618524213102281, 'min_data_in_leaf': 85, 'scale_pos_weight': 2.5266430926886985}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'learning_rate': FloatDistribution(high=0.1, log=True, low=0.01, step=None), 'max_depth': IntDistribution(high=8, log=False, low=4, step=1), 'l2_leaf_reg': FloatDistribution(high=10.0, log=True, low=0.001, step=None), 'subsample': FloatDistribution(high=1.0, log=False, low=0.4, step=None), 'colsample_bylevel': FloatDistribution(high=1.0, log=False, low=0.4, step=None), 'min_data_in_leaf': IntDistribution(high=100, log=False, low=5, step=1), 'scale_pos_weight': FloatDistribution(high=4.0, log=False, low=0.8, step=None)}, trial_id=51, value=None)
# Best XGBoost trial: FrozenTrial(number=17, state=TrialState.COMPLETE, values=[0.17291453494321074], datetime_start=datetime.datetime(2025, 6, 1, 19, 18, 37, 475515), datetime_complete=datetime.datetime(2025, 6, 1, 19, 19, 45, 483600), params={'learning_rate': 0.04882974463390442, 'max_depth': 7, 'lambda': 0.15843641121097743, 'alpha': 0.03984307113259465, 'subsample': 0.6683511046221176, 'colsample_bytree': 0.8721936294040624, 'colsample_bynode': 0.9401289020698028, 'scale_pos_weight': 2.6179652844639243}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'learning_rate': FloatDistribution(high=0.1, log=True, low=0.01, step=None), 'max_depth': IntDistribution(high=8, log=False, low=4, step=1), 'lambda': FloatDistribution(high=10.0, log=True, low=0.001, step=None), 'alpha': FloatDistribution(high=10.0, log=True, low=0.001, step=None), 'subsample': FloatDistribution(high=1.0, log=False, low=0.4, step=None), 'colsample_bytree': FloatDistribution(high=1.0, log=False, low=0.4, step=None), 'colsample_bynode': FloatDistribution(high=1.0, log=False, low=0.4, step=None), 'scale_pos_weight': FloatDistribution(high=4.0, log=False, low=0.8, step=None)}, trial_id=17, value=None)

# %% [markdown]
# TRAINING

# %% [markdown]
# LOOKING FOR FEATURE IMPORTANCE ( lgb + xgb )¶

# %%
from imblearn.pipeline import Pipeline as ImbPipeline


def create_lgb_pipeline(params):
    return ImbPipeline([
        ('sampler', RandomUnderSampler(sampling_strategy=sampling_ratio)),
        ('classifier', lgb.LGBMClassifier(
            objective='binary',
            verbosity=-1,
            n_estimators=200,
            random_state=42,
            **study_lgb.best_trial.params  # Распакуйте параметры
        )),
    ])

#  пайплайн с лучшими параметрами
lgb_estimator = create_lgb_pipeline(study_lgb.best_trial.params)
# Обучение
X, y = df_train_XGB_LGBM[feature_cols_with_OHE], df_train_XGB_LGBM[target_col]
lgb_estimator.fit(X, y)


def create_xgb_pipeline(params):
    return ImbPipeline([
        ('sampler', RandomUnderSampler(sampling_strategy=sampling_ratio)),
        ('classifier', xgb.XGBClassifier(
            objective='binary:logistic',
            n_estimators=200,
            tree_method='hist',
            random_state=42,
            **study_xgb.best_trial.params
        )),
    ])
# пайплайн с лучшими параметрами
xgb_estimator = create_xgb_pipeline(study_xgb.best_trial.params)
# Обучите модели
X, y = df_train_XGB_LGBM[feature_cols_with_OHE], df_train_XGB_LGBM[target_col]
xgb_estimator.fit(X, y)
# Out:
# Pipeline(steps=[('sampler', RandomUnderSampler(sampling_strategy=0.01)),
#                 ('classifier',
#                  XGBClassifier(alpha=0.03984307113259465, base_score=None,
#                                booster=None, callbacks=None,
#                                colsample_bylevel=None,
#                                colsample_bynode=0.9401289020698028,
#                                colsample_bytree=0.8721936294040624, device=None,
#                                early_stopping_rounds=None,
#                                enable_categorical=False, eval_metric=None,
#                                featu...row_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None,
#                                lambda=0.15843641121097743,
#                                learning_rate=0.04882974463390442, max_bin=None,
#                                max_cat_threshold=None, max_cat_to_onehot=None,
#                                max_delta_step=None, max_depth=7,
#                                max_leaves=None, min_child_weight=None,
#                                missing=nan, monotone_constraints=None,
#                                multi_strategy=None, n_estimators=200,
#                                n_jobs=None, ...))])

# %%
DO_FEATURE_IMPORTANCE_MODELS = True
DO_FEATURE_IMPORTANCE_TEST= True

# %%
if DO_FEATURE_IMPORTANCE_MODELS:
    # LightGBM feature importance
    lgb_model = lgb_estimator.named_steps['classifier']
    lgb_feature_importance = lgb_model.booster_.feature_importance(importance_type='gain')
    lgb_feature_importance_df = pd.DataFrame({
        'feature': X.columns,
        'importance': lgb_feature_importance
    }).sort_values(by='importance', ascending=False)

    print("LightGBM Feature Importance:")
    print(lgb_feature_importance_df)

    # XGBoost feature importance
    xgb_model = xgb_estimator.named_steps['classifier']
    xgb_feature_importance = xgb_model.get_booster().get_score(importance_type='weight')
    xgb_feature_importance_df = pd.DataFrame({
        'feature': list(xgb_feature_importance.keys()),
        'importance': list(xgb_feature_importance.values())
    }).sort_values(by='importance', ascending=False)

    print("XGBoost Feature Importance:")
    print(xgb_feature_importance_df)

    # Настройки отображения для Pandas
    pd.set_option('display.max_rows', 100)  # Количество отображаемых строк
    pd.set_option('display.max_columns', None)  # Количество отображаемых столбцов

    # Наименее важные признаки для LightGBM
    least_important_lgb = lgb_feature_importance_df.sort_values(by='importance').head(100)
    print("\nLeast Important Features in LightGBM:")
    print(least_important_lgb)

    # Наименее важные признаки для XGBoost
    least_important_xgb = xgb_feature_importance_df.sort_values(by='importance').head(100)
    print("\nLeast Important Features in XGBoost:")
    print(least_important_xgb)

    # Общие наименее важные признаки между LightGBM и XGBoost
    common_least_important_features = pd.merge(
        least_important_lgb[['feature']],
        least_important_xgb[['feature']],
        on='feature'
    )

    print("\nCommon Least Important Features in Both LightGBM and XGBoost:")
    print(common_least_important_features)
# Out:
# LightGBM Feature Importance:
#                                            feature    importance
# 157  age_normalized_nevi_confidence_2_patient_norm  12716.113711
# 8                                         tbp_lv_H   7014.563448
# 97                           tbp_lv_H_patient_norm   5442.551528
# 89                         age_approx_patient_norm   4087.237096
# 133           lesion_visibility_score_patient_norm   3266.709234
# ..                                             ...           ...
# 291                                      onehot_23      0.000000
# 293                                      onehot_25      0.000000
# 303                                      onehot_35      0.000000
# 304                                      onehot_36      0.000000
# 0                                       age_approx      0.000000
#
# [315 rows x 2 columns]
# XGBoost Feature Importance:
#                                            feature  importance
# 155  age_normalized_nevi_confidence_2_patient_norm       194.0
# 176                              count_per_patient       114.0
# 95                           tbp_lv_H_patient_norm       108.0
# 1                           clin_size_long_diam_mm        91.0
# 87                         age_approx_patient_norm        87.0
# ..                                             ...         ...
# 216                 border_complexity_patient_mean         1.0
# 282                                      onehot_44         1.0
# 223       consistency_symmetry_border_patient_mean         1.0
# 264                                       onehot_1         1.0
# 271                                      onehot_11         1.0
#
# [285 rows x 2 columns]
#
# Least Important Features in LightGBM:
#                                          feature  importance
# 0                                     age_approx    0.000000
# 304                                    onehot_36    0.000000
# 303                                    onehot_35    0.000000
# 293                                    onehot_25    0.000000
# 291                                    onehot_23    0.000000
# 292                                    onehot_24    0.000000
# 289                                    onehot_21    0.000000
# 290                                    onehot_22    0.000000
# 81                            lesion_circularity    0.000000
# 76                            lesion_compactness    0.000000
# 255              lesion_compactness_patient_mean    0.000000
# 82                          volume_to_area_ratio    0.000000
# 312                                    onehot_44    0.000000
# 300                                    onehot_32    0.000000
# 285                                    onehot_17    0.000000
# 284                                    onehot_16    0.000000
# 286                                    onehot_18    0.000000
# 287                                    onehot_19    0.000000
# 54                               log_lesion_area    0.000000
# 274                                     onehot_6    0.000000
# 271                                     onehot_3    0.000000
# 283                                    onehot_15    0.000000
# 296                                    onehot_28    0.000000
# 307                                    onehot_39    0.000000
# 305                                    onehot_37    0.000000
# 306                                    onehot_38    0.000000
# 282                                    onehot_14    0.000000
# 281                                    onehot_13    0.000000
# 299                                    onehot_31    0.000000
# 280                                    onehot_12    0.000000
# 279                                    onehot_11    0.000000
# 276                                     onehot_8    0.000000
# 275                                     onehot_7    0.000000
# 165              lesion_compactness_patient_norm    0.000000
# 57                              std_dev_contrast    0.000000
# 236                std_dev_contrast_patient_mean    0.000000
# 231          shape_complexity_index_patient_mean    0.000000
# 146                std_dev_contrast_patient_norm    0.000000
# 261            volume_to_area_ratio_patient_mean    0.000000
# 260              lesion_circularity_patient_mean    0.000000
# 268                                     onehot_0    0.000000
# 225     consistency_symmetry_border_patient_mean    0.000000
# 170              lesion_circularity_patient_norm    0.000000
# 171            volume_to_area_ratio_patient_norm    0.000000
# 311                                    onehot_43    0.000000
# 310                                    onehot_42    0.000000
# 208               tbp_lv_symm_2axis_patient_mean    1.566697
# 197                  tbp_lv_deltaLB_patient_mean    2.406900
# 179                      age_approx_patient_mean    2.911970
# 73                           border_length_ratio    3.360360
# 116                     tbp_lv_stdL_patient_norm    5.629594
# 144          normalized_lesion_size_patient_norm    5.886492
# 294                                    onehot_26    6.064140
# 297                                    onehot_29    6.146650
# 314                                    onehot_46    6.428880
# 270                                     onehot_2    6.649730
# 269                                     onehot_1    6.969120
# 216              luminance_contrast_patient_mean    7.206190
# 302                                    onehot_34    7.464160
# 308                                    onehot_40    8.061140
# 278                                    onehot_10    9.392030
# 309                                    onehot_41    9.589250
# 301                                    onehot_33   10.144550
# 192         tbp_lv_area_perim_ratio_patient_mean   10.268760
# 223         lesion_visibility_score_patient_mean   10.502383
# 298                                    onehot_30   10.569240
# 37                            luminance_contrast   10.980010
# 141          shape_complexity_index_patient_norm   11.148716
# 27                                   tbp_lv_stdL   12.221205
# 14                         tbp_lv_color_std_mean   12.380246
# 128               border_complexity_patient_norm   13.616539
# 288                                    onehot_20   13.934820
# 13                       tbp_lv_area_perim_ratio   14.442038
# 162             border_length_ratio_patient_norm   15.659190
# 202              tbp_lv_norm_border_patient_mean   16.995805
# 194                   tbp_lv_deltaA_patient_mean   17.556141
# 259      lesion_color_contrast_norm_patient_mean   18.153389
# 218               border_complexity_patient_mean   18.271750
# 295                                    onehot_27   18.574060
# 272                                     onehot_4   20.718460
# 87                             color_homogeneity   20.932020
# 205     tbp_lv_radial_color_std_max_patient_mean   21.791105
# 103           tbp_lv_color_std_mean_patient_norm   22.322116
# 240  symmetry_perimeter_interaction_patient_mean   24.386586
# 134     symmetry_border_consistency_patient_norm   27.585760
# 257       border_irregularity_index_patient_mean   27.782026
# 50                     hue_color_std_interaction   28.820895
# 17                                 tbp_lv_deltaL   29.046500
# 256               ellipticity_index_patient_mean   29.203100
# 252             border_length_ratio_patient_mean   30.219330
# 34                             lesion_size_ratio   32.681378
# 107                  tbp_lv_deltaLB_patient_norm   32.981090
# 45                   symmetry_border_consistency   33.499080
# 221         perimeter_to_area_ratio_patient_mean   35.134640
# 204              tbp_lv_perimeterMM_patient_mean   36.600050
# 206                     tbp_lv_stdL_patient_mean   36.706140
# 196                   tbp_lv_deltaL_patient_mean   37.084630
# 30                       tbp_lv_symm_2axis_angle   37.484110
# 106                   tbp_lv_deltaL_patient_norm   40.246156
# 137               consistency_color_patient_norm   41.259864
#
# Least Important Features in XGBoost:
#                                            feature  importance
# 271                                      onehot_11         1.0
# 264                                       onehot_1         1.0
# 223       consistency_symmetry_border_patient_mean         1.0
# 282                                      onehot_44         1.0
# 216                 border_complexity_patient_mean         1.0
# 251                lesion_compactness_patient_mean         1.0
# 163                lesion_compactness_patient_norm         1.0
# 281                                      onehot_42         1.0
# 274                                      onehot_16         1.0
# 278                                      onehot_30         1.0
# 280                                      onehot_41         1.0
# 275                                      onehot_20         2.0
# 233                  std_dev_contrast_patient_mean         2.0
# 54                                 log_lesion_area         2.0
# 168                lesion_circularity_patient_norm         2.0
# 265                                       onehot_2         2.0
# 272                                      onehot_13         2.0
# 263                                       onehot_0         3.0
# 73                             border_length_ratio         3.0
# 277                                      onehot_29         3.0
# 139            shape_complexity_index_patient_norm         3.0
# 279                                      onehot_40         3.0
# 253         border_irregularity_index_patient_mean         4.0
# 268                                       onehot_7         4.0
# 14                           tbp_lv_color_std_mean         4.0
# 206                 tbp_lv_symm_2axis_patient_mean         4.0
# 222       symmetry_border_consistency_patient_mean         5.0
# 80                            volume_to_area_ratio         5.0
# 37                              luminance_contrast         5.0
# 35                              lesion_shape_index         5.0
# 284                                      onehot_46         5.0
# 177                        age_approx_patient_mean         5.0
# 164                 ellipticity_index_patient_norm         5.0
# 256              volume_to_area_ratio_patient_mean         5.0
# 273                                      onehot_14         5.0
# 214                luminance_contrast_patient_mean         5.0
# 124                luminance_contrast_patient_norm         5.0
# 276                                      onehot_27         6.0
# 266                                       onehot_4         6.0
# 219           perimeter_to_area_ratio_patient_mean         7.0
# 50                       hue_color_std_interaction         7.0
# 57                                std_dev_contrast         7.0
# 200                tbp_lv_norm_border_patient_mean         7.0
# 221           lesion_visibility_score_patient_mean         7.0
# 190           tbp_lv_area_perim_ratio_patient_mean         7.0
# 48                               consistency_color         7.0
# 269                                       onehot_8         7.0
# 186                       tbp_lv_Hext_patient_mean         8.0
# 267                                       onehot_5         8.0
# 52                          shape_complexity_index         8.0
# 144                  std_dev_contrast_patient_norm         8.0
# 0                                       age_approx         8.0
# 204                       tbp_lv_stdL_patient_mean         9.0
# 225                 consistency_color_patient_mean         9.0
# 212                lesion_shape_index_patient_mean        10.0
# 220           area_to_perimeter_ratio_patient_mean        10.0
# 201                 tbp_lv_norm_color_patient_mean        10.0
# 252                 ellipticity_index_patient_mean        10.0
# 126                 border_complexity_patient_norm        10.0
# 133       consistency_symmetry_border_patient_norm        10.0
# 136              size_age_interaction_patient_norm        11.0
# 154    age_normalized_nevi_confidence_patient_norm        11.0
# 116                 tbp_lv_symm_2axis_patient_norm        11.0
# 270                                       onehot_9        11.0
# 165         border_irregularity_index_patient_norm        11.0
# 142            normalized_lesion_size_patient_norm        11.0
# 203       tbp_lv_radial_color_std_max_patient_mean        11.0
# 227         hue_color_std_interaction_patient_mean        12.0
# 248           shape_color_consistency_patient_mean        12.0
# 160               border_length_ratio_patient_norm        13.0
# 76                               ellipticity_index        13.0
# 135                 consistency_color_patient_norm        13.0
# 244  age_normalized_nevi_confidence_2_patient_mean        13.0
# 152        border_color_interaction_2_patient_norm        13.0
# 255        lesion_color_contrast_norm_patient_mean        13.0
# 191             tbp_lv_color_std_mean_patient_mean        13.0
# 110                tbp_lv_norm_border_patient_norm        14.0
# 199            tbp_lv_nevi_confidence_patient_mean        14.0
# 85                               color_homogeneity        14.0
# 159           shape_color_consistency_patient_norm        14.0
# 24                               tbp_lv_norm_color        14.0
# 43                         area_to_perimeter_ratio        14.0
# 46                     consistency_symmetry_border        15.0
# 169              volume_to_area_ratio_patient_norm        15.0
# 72                         shape_color_consistency        15.0
# 23                              tbp_lv_norm_border        15.0
# 39                               border_complexity        16.0
# 234       color_shape_composite_index_patient_mean        16.0
# 29                               tbp_lv_symm_2axis        16.0
# 65                      border_color_interaction_2        16.0
# 198                tbp_lv_minorAxisMM_patient_mean        16.0
# 27                                     tbp_lv_stdL        16.0
# 194                     tbp_lv_deltaL_patient_mean        17.0
# 61                  symmetry_perimeter_interaction        17.0
# 148    symmetry_perimeter_interaction_patient_norm        17.0
# 202                tbp_lv_perimeterMM_patient_mean        17.0
# 69                           color_asymmetry_index        18.0
# 195                    tbp_lv_deltaLB_patient_mean        18.0
# 237    symmetry_perimeter_interaction_patient_mean        18.0
# 64                        border_color_interaction        18.0
#
# Common Least Important Features in Both LightGBM and XGBoost:
#                                         feature
# 0                                    age_approx
# 1               lesion_compactness_patient_mean
# 2                          volume_to_area_ratio
# 3                                     onehot_44
# 4                                     onehot_16
# 5                               log_lesion_area
# 6                                     onehot_14
# 7                                     onehot_13
# 8                                     onehot_11
# 9                                      onehot_8
# 10                                     onehot_7
# 11              lesion_compactness_patient_norm
# 12                             std_dev_contrast
# 13                std_dev_contrast_patient_mean
# 14                std_dev_contrast_patient_norm
# 15            volume_to_area_ratio_patient_mean
# 16                                     onehot_0
# 17     consistency_symmetry_border_patient_mean
# 18              lesion_circularity_patient_norm
# 19            volume_to_area_ratio_patient_norm
# 20                                    onehot_42
# 21               tbp_lv_symm_2axis_patient_mean
# 22                  tbp_lv_deltaLB_patient_mean
# 23                      age_approx_patient_mean
# 24                          border_length_ratio
# 25          normalized_lesion_size_patient_norm
# 26                                    onehot_29
# 27                                    onehot_46
# 28                                     onehot_2
# 29                                     onehot_1
# 30              luminance_contrast_patient_mean
# 31                                    onehot_40
# 32                                    onehot_41
# 33         tbp_lv_area_perim_ratio_patient_mean
# 34         lesion_visibility_score_patient_mean
# 35                                    onehot_30
# 36                           luminance_contrast
# 37          shape_complexity_index_patient_norm
# 38                                  tbp_lv_stdL
# 39                        tbp_lv_color_std_mean
# 40               border_complexity_patient_norm
# 41                                    onehot_20
# 42             border_length_ratio_patient_norm
# 43              tbp_lv_norm_border_patient_mean
# 44      lesion_color_contrast_norm_patient_mean
# 45               border_complexity_patient_mean
# 46                                    onehot_27
# 47                                     onehot_4
# 48                            color_homogeneity
# 49     tbp_lv_radial_color_std_max_patient_mean
# 50  symmetry_perimeter_interaction_patient_mean
# 51       border_irregularity_index_patient_mean
# 52                    hue_color_std_interaction
# 53               ellipticity_index_patient_mean
# 54         perimeter_to_area_ratio_patient_mean
# 55              tbp_lv_perimeterMM_patient_mean
# 56                     tbp_lv_stdL_patient_mean
# 57                   tbp_lv_deltaL_patient_mean
# 58               consistency_color_patient_norm

# %%
def create_cat_pipeline(params):
    return ImbPipeline([
        ('sampler', RandomUnderSampler(sampling_strategy=sampling_ratio)),
        ('classifier', cb.CatBoostClassifier(
            loss_function='Logloss',
            iterations=200,
            random_seed=42,
            silent=True,
            cat_features= cat_cols,
            **study_cb.best_trial.params  # Используем параметры, переданные в функцию
        )),
    ])

# Создание и обучение модели CatBoost
cat_estimator = create_cat_pipeline(study_cb.best_trial.params)
X, y = df_train_XGB_LGBM[feature_cols_without_OHE], df_train_XGB_LGBM[target_col]
cat_estimator.fit(X, y)

if DO_FEATURE_IMPORTANCE_MODELS:
    # CatBoost feature importance
    cat_model = cat_estimator.named_steps['classifier']
    cat_feature_importance = cat_model.get_feature_importance()
    cat_feature_importance_df = pd.DataFrame({
        'feature': X.columns,
        'importance': cat_feature_importance
    }).sort_values(by='importance', ascending=False)

    print("CatBoost Feature Importance:")
    print(cat_feature_importance_df)

    # Настройки отображения для Pandas
    pd.set_option('display.max_rows', 100)  # Количество отображаемых строк
    pd.set_option('display.max_columns', None)  # Количество отображаемых столбцов

    # Наименее важные признаки для CatBoost
    least_important_cat = cat_feature_importance_df.sort_values(by='importance').head(100)
    print("\nLeast Important Features in CatBoost:")
    print(least_important_cat)

    # Сохранение результатов feature importance для всех трех моделей
    common_least_important_features = pd.merge(
        least_important_lgb[['feature']],
        least_important_xgb[['feature']],
        on='feature'
    ).merge(least_important_cat[['feature']], on='feature')

    print("\nCommon Least Important Features in LightGBM, XGBoost, and CatBoost:")
    print(common_least_important_features)
# Out:
# CatBoost Feature Importance:
#                                     feature  importance
# 103                   tbp_lv_H_patient_norm    2.911975
# 8                                  tbp_lv_H    2.363092
# 104                tbp_lv_Hext_patient_norm    2.014676
# 38                  lesion_color_difference    1.696822
# 36                             hue_contrast    1.668643
# ..                                      ...         ...
# 186     clin_size_long_diam_mm_patient_mean    0.000000
# 93                   tbp_lv_location_simple    0.000000
# 263  border_irregularity_index_patient_mean    0.000000
# 242           std_dev_contrast_patient_mean    0.000000
# 220         lesion_shape_index_patient_mean    0.000000
#
# [274 rows x 2 columns]
#
# Least Important Features in CatBoost:
#                                          feature  importance
# 220              lesion_shape_index_patient_mean    0.000000
# 269  gradient_based_color_asymmetry_patient_mean    0.000000
# 242                std_dev_contrast_patient_mean    0.000000
# 263       border_irregularity_index_patient_mean    0.000000
# 186          clin_size_long_diam_mm_patient_mean    0.000000
# 93                        tbp_lv_location_simple    0.000000
# 51                         lesion_severity_index    0.000000
# 124               tbp_lv_symm_2axis_patient_norm    0.000000
# 50                     hue_color_std_interaction    0.000000
# 92                               tbp_lv_location    0.000000
# 194                     tbp_lv_Hext_patient_mean    0.001422
# 265      lesion_color_contrast_norm_patient_mean    0.016684
# 78                     border_irregularity_index    0.018774
# 63                          color_variance_ratio    0.022001
# 217                        tbp_lv_y_patient_mean    0.023042
# 80                    lesion_color_contrast_norm    0.024942
# 258             border_length_ratio_patient_mean    0.025690
# 141     consistency_symmetry_border_patient_norm    0.026632
# 143               consistency_color_patient_norm    0.030144
# 114              tbp_lv_deltaLBnorm_patient_norm    0.030385
# 100                     tbp_lv_Bext_patient_norm    0.031404
# 200                   tbp_lv_deltaA_patient_mean    0.031698
# 69                         color_asymmetry_index    0.031716
# 17                                 tbp_lv_deltaL    0.035155
# 16                                 tbp_lv_deltaB    0.036283
# 52                        shape_complexity_index    0.042026
# 27                                   tbp_lv_stdL    0.044183
# 171              lesion_compactness_patient_norm    0.045130
# 85                 symmetry_to_compactness_ratio    0.050906
# 18                                tbp_lv_deltaLB    0.058798
# 178             lesion_spread_index_patient_norm    0.060554
# 140     symmetry_border_consistency_patient_norm    0.061938
# 248            color_variance_ratio_patient_mean    0.063050
# 235       hue_color_std_interaction_patient_mean    0.064444
# 233               consistency_color_patient_mean    0.065550
# 122                     tbp_lv_stdL_patient_norm    0.065688
# 224               border_complexity_patient_mean    0.066720
# 169         age_size_symmetry_index_patient_norm    0.067119
# 214               tbp_lv_symm_2axis_patient_mean    0.067482
# 273    border_to_hue_contrast_ratio_patient_mean    0.072712
# 29                             tbp_lv_symm_2axis    0.073031
# 228         area_to_perimeter_ratio_patient_mean    0.073137
# 20                           tbp_lv_eccentricity    0.073826
# 261              lesion_compactness_patient_mean    0.076511
# 158            color_variance_ratio_patient_norm    0.078742
# 47                             color_consistency    0.081726
# 199           tbp_lv_color_std_mean_patient_mean    0.084770
# 118              tbp_lv_norm_border_patient_norm    0.085215
# 208              tbp_lv_norm_border_patient_mean    0.087856
# 166                     color_range_patient_norm    0.088332
# 2                                       tbp_lv_A    0.092298
# 35                            lesion_shape_index    0.093026
# 145       hue_color_std_interaction_patient_norm    0.093128
# 39                             border_complexity    0.094428
# 125         tbp_lv_symm_2axis_angle_patient_norm    0.095161
# 130              lesion_shape_index_patient_norm    0.095648
# 84                gradient_based_color_asymmetry    0.096522
# 129               lesion_size_ratio_patient_norm    0.096656
# 109           tbp_lv_color_std_mean_patient_norm    0.096793
# 115             tbp_lv_eccentricity_patient_norm    0.097575
# 227         perimeter_to_area_ratio_patient_mean    0.097996
# 236           lesion_severity_index_patient_mean    0.099376
# 44                       lesion_visibility_score    0.118035
# 244           lesion_orientation_3d_patient_mean    0.118113
# 90                           anatom_site_general    0.118148
# 187                        tbp_lv_A_patient_mean    0.119718
# 191                        tbp_lv_C_patient_mean    0.122053
# 246  symmetry_perimeter_interaction_patient_mean    0.123757
# 59                         lesion_orientation_3d    0.123972
# 231     consistency_symmetry_border_patient_mean    0.124481
# 188                     tbp_lv_Aext_patient_mean    0.127859
# 168             border_length_ratio_patient_norm    0.132126
# 221                    hue_contrast_patient_mean    0.134585
# 203                  tbp_lv_deltaLB_patient_mean    0.135325
# 0                                     age_approx    0.136552
# 45                   symmetry_border_consistency    0.138292
# 54                               log_lesion_area    0.139009
# 173       border_irregularity_index_patient_norm    0.139386
# 46                   consistency_symmetry_border    0.139904
# 206              tbp_lv_minorAxisMM_patient_mean    0.141236
# 255         volume_approximation_3d_patient_mean    0.142210
# 99                         tbp_lv_B_patient_norm    0.143500
# 156  symmetry_perimeter_interaction_patient_norm    0.146848
# 64                      border_color_interaction    0.147413
# 81                            lesion_circularity    0.149678
# 270   symmetry_to_compactness_ratio_patient_mean    0.154273
# 216                        tbp_lv_x_patient_mean    0.156989
# 176              lesion_circularity_patient_norm    0.159566
# 72                       shape_color_consistency    0.159962
# 190                     tbp_lv_Bext_patient_mean    0.160066
# 211     tbp_lv_radial_color_std_max_patient_mean    0.160168
# 138         area_to_perimeter_ratio_patient_norm    0.166831
# 147          shape_complexity_index_patient_norm    0.168431
# 14                         tbp_lv_color_std_mean    0.171344
# 179  gradient_based_color_asymmetry_patient_norm    0.174155
# 205             tbp_lv_eccentricity_patient_mean    0.178339
# 159        border_color_interaction_patient_norm    0.180952
# 86                 age_normalized_severity_index    0.183130
# 210              tbp_lv_perimeterMM_patient_mean    0.184011
# 243     color_shape_composite_index_patient_mean    0.187288
#
# Common Least Important Features in LightGBM, XGBoost, and CatBoost:
#                                         feature
# 0                                    age_approx
# 1               lesion_compactness_patient_mean
# 2                               log_lesion_area
# 3               lesion_compactness_patient_norm
# 4                 std_dev_contrast_patient_mean
# 5      consistency_symmetry_border_patient_mean
# 6               lesion_circularity_patient_norm
# 7                tbp_lv_symm_2axis_patient_mean
# 8                   tbp_lv_deltaLB_patient_mean
# 9           shape_complexity_index_patient_norm
# 10                                  tbp_lv_stdL
# 11                        tbp_lv_color_std_mean
# 12             border_length_ratio_patient_norm
# 13              tbp_lv_norm_border_patient_mean
# 14      lesion_color_contrast_norm_patient_mean
# 15               border_complexity_patient_mean
# 16     tbp_lv_radial_color_std_max_patient_mean
# 17  symmetry_perimeter_interaction_patient_mean
# 18       border_irregularity_index_patient_mean
# 19                    hue_color_std_interaction
# 20         perimeter_to_area_ratio_patient_mean
# 21              tbp_lv_perimeterMM_patient_mean
# 22               consistency_color_patient_norm

# %%
"""TEST PREDICTION"""

# Ensure df_subm has the correct structure
df_subm = df_subm.reset_index()  # This moves isic_id from index to column

# Predictions for each model
lgb_predictions = lgb_estimator.predict_proba(df_test[feature_cols_with_OHE])[:, 1]
xgb_predictions = xgb_estimator.predict_proba(df_test[feature_cols_with_OHE])[:, 1]
cat_predictions = cat_estimator.predict_proba(df_test[feature_cols_without_OHE])[:, 1]

# Individual model submissions (optional)
df_subm_temp = df_subm.copy()
df_subm_temp['target'] = lgb_predictions
df_subm_temp[['isic_id', 'target']].to_csv('submission_lgb.csv', index=False)

df_subm_temp['target'] = xgb_predictions
df_subm_temp[['isic_id', 'target']].to_csv('submission_xgb.csv', index=False)

df_subm_temp['target'] = cat_predictions
df_subm_temp[['isic_id', 'target']].to_csv('submission_cat.csv', index=False)

# Average predictions
average_predictions = (lgb_predictions + xgb_predictions + cat_predictions) / 3

# Create proper submission DataFrame
df_subm['target'] = average_predictions

# Save with proper format - keep the isic_id column
df_subm[['isic_id', 'target']].to_csv('submission.csv', index=False)

display(df_subm[['isic_id', 'target']].head())
# Out:
#         isic_id    target
# 0  ISIC_0015657  0.696720
# 1  ISIC_0015729  0.615805
# 2  ISIC_0015740  0.674890
